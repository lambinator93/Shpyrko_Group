# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.widgets import Slider, Button, RadioButtons

filename1 = 'scan_0224.nxs'
filename2 = 'scan_0225.nxs'
filename3 = 'scan_0226.nxs'
filename4 = 'scan_0227.nxs'
f1 = h5py.File(filename1, 'r') #must declare object here to use throughout 
f2 = h5py.File(filename2, 'r') #must declare object here to use throughout 
f3 = h5py.File(filename3, 'r') #must declare object here to use throughout 
f4 = h5py.File(filename4, 'r') #must declare object here to use throughout 



#with h5py.File(filename, 'r') as f: f is an object that only exists within 'with' environment
# List all groups
print("Keys: %s" % f1.keys())
a_group_key = list(f1.keys())[0]

# Get the data
data = list(f1[a_group_key])

for i in range(0,len(data)):
    print('data[%s] = %s' % (i,data[i]))
# Out:
# Keys: <KeysViewHDF5 ['scan_0224']>
# data[0] = SEXTANTS
# data[1] = User
# data[2] = duration
# data[3] = end_time
# data[4] = proposal_number
# data[5] = proposal_title
# data[6] = run_cycle
# data[7] = scan_config
# data[8] = scan_data
# data[9] = start_time

# %%
#gset = f[a_group_key]
#gset[data[8]]
en1 = list(f1['/scan_0224/scan_data/data_15/'])
det1 = list(f1['/scan_0224/scan_data/data_17/'])

#en2 = list(f2['/scan_0225/scan_data/data_15/'])
#det2 = list(f2['/scan_0225/scan_data/data_17/'])

#en3 = list(f3['/scan_0226/scan_data/data_15/'])
#det3 = list(f3['/scan_0226/scan_data/data_17/'])

#en4 = list(f4['/scan_0227/scan_data/data_15/'])
#det4 = list(f4['/scan_0227/scan_data/data_17/'])



#det1[0]

# %%
det1[0][2047,2047]
len(en)
# Out:
# 101

# %%
l = plt.imshow(det1[10])
#l.set_clim(0,0.5)

# %%
plt.imshow(det2[75])
